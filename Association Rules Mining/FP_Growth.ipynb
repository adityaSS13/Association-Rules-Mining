# %%
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null

# %%
#!wget -q https://www-us.apache.org/dist/spark/spark-3.0.1/spark-3.0.1-bin-hadoop2.7.tgz
# !wget -q https://dlcdn.apache.org/spark/spark-3.5.0/spark-3.5.0-bin-hadoop3.tgz

# %%
# !tar xf spark-3.5.0-bin-hadoop3.tgz

# %%
# !pip install -q findspark

# %%
import os
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
os.environ["SPARK_HOME"] = "/content/spark-3.5.0-bin-hadoop3"

# %%
import findspark
findspark.init()

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("AR Mining").getOrCreate()

# %%
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

file_path = "data.csv"
data = spark.read.csv(file_path, header=True, inferSchema=True)
#data.show(5)

# %%
data = data.dropna()
columns_to_drop = ['lat', 'lng', 'desc', 'timeStamp', 'addr', 'title', 'zip']
data = data.drop(*columns_to_drop)
data.show(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# +-----------------+-------+------------------+------+-----------+------------+
# |              twp|service|              type|season|time_of_day|time_of_week|
# +-----------------+-------+------------------+------+-----------+------------+
# |      NEW HANOVER|    EMS| BACK PAINS/INJURY|winter|    evening|     weekday|
# |HATFIELD TOWNSHIP|    EMS|DIABETIC EMERGENCY|winter|    evening|     weekday|
# |       NORRISTOWN|   Fire|     GAS-ODOR/LEAK|winter|  afternoon|     weekday|
# |       NORRISTOWN|    EMS| CARDIAC EMERGENCY|winter|  afternoon|     weekday|
# | LOWER POTTSGROVE|    EMS|         DIZZINESS|winter|  afternoon|     weekday|
# +-----------------+-------+------------------+------+-----------+------------+
# only showing top 5 rows

# %%
import numpy as np
from pyspark.ml.fpm import FPGrowth
from pyspark.sql.functions import split
from pyspark.sql.functions import array, col

# Assuming 'col1', 'col2', 'col3' are columns you want to use as antecedents
antecedent_cols = ['twp', 'service', 'type', 'season', 'time_of_day', 'time_of_week']

# Merging multiple columns into a single array column
data = data.withColumn("items", array(*[col(col_name) for col_name in antecedent_cols]))

# Selecting the merged column as transactions
transactions = data.select("items")

# Create an FPGrowth instance
fp_growth = FPGrowth(itemsCol="items", minSupport=0.01, minConfidence=0.2)

# Fit the model on your data
model = fp_growth.fit(transactions)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
model.freqItemsets.show(truncate=False, n=200)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# +-------------------------------------------------------+------+
# |items                                                  |freq  |
# +-------------------------------------------------------+------+
# |[HEAD INJURY]                                          |17204 |
# |[HEAD INJURY, EMS]                                     |17201 |
# |[HEAD INJURY, EMS, weekday]                            |12367 |
# |[HEAD INJURY, weekday]                                 |12370 |
# |[UNKNOWN MEDICAL EMERGENCY]                            |9925  |
# |[UNKNOWN MEDICAL EMERGENCY, EMS]                       |9923  |
# |[UNKNOWN MEDICAL EMERGENCY, EMS, weekday]              |7161  |
# |[UNKNOWN MEDICAL EMERGENCY, weekday]                   |7163  |
# |[NAUSEA/VOMITING]                                      |7214  |
# |[NAUSEA/VOMITING, EMS]                                 |7212  |
# |[WEST NORRITON]                                        |10582 |
# |[WEST NORRITON, weekday]                               |7922  |
# |[spring]                                               |161780|
# |[spring, Traffic]                                      |54959 |
# |[spring, Traffic, weekday]                             |43107 |
# |[spring, VEHICLE ACCIDENT]                             |43493 |
# |[spring, VEHICLE ACCIDENT, Traffic]                    |35041 |
# |[spring, VEHICLE ACCIDENT, Traffic, weekday]           |27519 |
# |[spring, VEHICLE ACCIDENT, morning]                    |12890 |
# |[spring, VEHICLE ACCIDENT, morning, Traffic]           |10456 |
# |[spring, VEHICLE ACCIDENT, morning, Traffic, weekday]  |8602  |
# |[spring, VEHICLE ACCIDENT, morning, weekday]           |10498 |
# |[spring, VEHICLE ACCIDENT, afternoon]                  |17078 |
# |[spring, VEHICLE ACCIDENT, afternoon, Traffic]         |14019 |
# |[spring, VEHICLE ACCIDENT, afternoon, Traffic, weekday]|10914 |
# |[spring, VEHICLE ACCIDENT, afternoon, weekday]         |13277 |
# |[spring, VEHICLE ACCIDENT, weekday]                    |33866 |
# |[spring, morning]                                      |48266 |
# |[spring, morning, Traffic]                             |16410 |
# |[spring, morning, Traffic, weekday]                    |13266 |
# |[spring, morning, EMS]                                 |25195 |
# |[spring, morning, EMS, weekday]                        |18984 |
# |[spring, morning, weekday]                             |37334 |
# |[spring, EMS]                                          |82357 |
# |[spring, EMS, weekday]                                 |60366 |
# |[spring, afternoon]                                    |54010 |
# |[spring, afternoon, Traffic]                           |21078 |
# |[spring, afternoon, Traffic, weekday]                  |16593 |
# |[spring, afternoon, EMS]                               |24878 |
# |[spring, afternoon, EMS, weekday]                      |18508 |
# |[spring, afternoon, weekday]                           |41157 |
# |[spring, evening]                                      |42619 |
# |[spring, evening, Traffic]                             |14153 |
# |[spring, evening, Traffic, weekday]                    |11189 |
# |[spring, evening, VEHICLE ACCIDENT]                    |11035 |
# |[spring, evening, VEHICLE ACCIDENT, Traffic]           |8763  |
# |[spring, evening, VEHICLE ACCIDENT, Traffic, weekday]  |6958  |
# |[spring, evening, VEHICLE ACCIDENT, weekday]           |8677  |
# |[spring, evening, EMS]                                 |21082 |
# |[spring, evening, EMS, weekday]                        |15210 |
# |[spring, evening, weekday]                             |31787 |
# |[spring, weekday]                                      |121524|
# |[UPPER MORELAND]                                       |21741 |
# |[UPPER MORELAND, Traffic]                              |8056  |
# |[UPPER MORELAND, Traffic, weekday]                     |6398  |
# |[UPPER MORELAND, VEHICLE ACCIDENT]                     |6375  |
# |[UPPER MORELAND, morning]                              |6584  |
# |[UPPER MORELAND, EMS]                                  |11251 |
# |[UPPER MORELAND, EMS, weekday]                         |8365  |
# |[UPPER MORELAND, afternoon]                            |7301  |
# |[UPPER MORELAND, weekday]                              |16557 |
# |[UPPER GWYNEDD]                                        |8400  |
# |[UPPER GWYNEDD, weekday]                               |6574  |
# |[EAST NORRITON]                                        |13251 |
# |[EAST NORRITON, EMS]                                   |7962  |
# |[EAST NORRITON, weekday]                               |9935  |
# |[FALL VICTIM]                                          |32622 |
# |[FALL VICTIM, spring]                                  |8657  |
# |[FALL VICTIM, spring, EMS]                             |8656  |
# |[FALL VICTIM, spring, EMS, weekday]                    |6333  |
# |[FALL VICTIM, spring, weekday]                         |6334  |
# |[FALL VICTIM, fall]                                    |7271  |
# |[FALL VICTIM, fall, EMS]                               |7267  |
# |[FALL VICTIM, morning]                                 |10281 |
# |[FALL VICTIM, morning, EMS]                            |10279 |
# |[FALL VICTIM, morning, EMS, weekday]                   |7662  |
# |[FALL VICTIM, morning, weekday]                        |7664  |
# |[FALL VICTIM, winter]                                  |8620  |
# |[FALL VICTIM, winter, EMS]                             |8620  |
# |[FALL VICTIM, winter, EMS, weekday]                    |6288  |
# |[FALL VICTIM, winter, weekday]                         |6288  |
# |[FALL VICTIM, EMS]                                     |32615 |
# |[FALL VICTIM, EMS, weekday]                            |23683 |
# |[FALL VICTIM, weekend]                                 |8932  |
# |[FALL VICTIM, weekend, EMS]                            |8932  |
# |[FALL VICTIM, summer]                                  |8074  |
# |[FALL VICTIM, summer, EMS]                             |8072  |
# |[FALL VICTIM, afternoon]                               |9491  |
# |[FALL VICTIM, afternoon, EMS]                          |9490  |
# |[FALL VICTIM, afternoon, EMS, weekday]                 |6898  |
# |[FALL VICTIM, afternoon, weekday]                      |6899  |
# |[FALL VICTIM, evening]                                 |8103  |
# |[FALL VICTIM, evening, EMS]                            |8100  |
# |[FALL VICTIM, weekday]                                 |23690 |
# |[Traffic]                                              |220320|
# |[Traffic, weekday]                                     |172435|
# |[LOWER MERION]                                         |52596 |
# |[LOWER MERION, spring]                                 |13518 |
# |[LOWER MERION, spring, weekday]                        |10167 |
# |[LOWER MERION, fall]                                   |12073 |
# |[LOWER MERION, fall, weekday]                          |9083  |
# |[LOWER MERION, Traffic]                                |22756 |
# |[LOWER MERION, Traffic, weekday]                       |17733 |
# |[LOWER MERION, VEHICLE ACCIDENT]                       |17332 |
# |[LOWER MERION, VEHICLE ACCIDENT, Traffic]              |14154 |
# |[LOWER MERION, VEHICLE ACCIDENT, Traffic, weekday]     |11346 |
# |[LOWER MERION, VEHICLE ACCIDENT, afternoon]            |6884  |
# |[LOWER MERION, VEHICLE ACCIDENT, weekday]              |13697 |
# |[LOWER MERION, morning]                                |15939 |
# |[LOWER MERION, morning, Traffic]                       |6781  |
# |[LOWER MERION, morning, EMS]                           |6304  |
# |[LOWER MERION, morning, weekday]                       |12314 |
# |[LOWER MERION, winter]                                 |13425 |
# |[LOWER MERION, winter, weekday]                        |10051 |
# |[LOWER MERION, EMS]                                    |20252 |
# |[LOWER MERION, EMS, weekday]                           |14855 |
# |[LOWER MERION, weekend]                                |12983 |
# |[LOWER MERION, summer]                                 |13580 |
# |[LOWER MERION, summer, weekday]                        |10312 |
# |[LOWER MERION, Fire]                                   |9588  |
# |[LOWER MERION, Fire, weekday]                          |7025  |
# |[LOWER MERION, afternoon]                              |18029 |
# |[LOWER MERION, afternoon, Traffic]                     |8555  |
# |[LOWER MERION, afternoon, Traffic, weekday]            |6738  |
# |[LOWER MERION, afternoon, EMS]                         |6498  |
# |[LOWER MERION, afternoon, weekday]                     |13818 |
# |[LOWER MERION, evening]                                |13804 |
# |[LOWER MERION, evening, weekday]                       |10352 |
# |[LOWER MERION, weekday]                                |39613 |
# |[LOWER MORELAND]                                       |10385 |
# |[LOWER MORELAND, weekday]                              |7988  |
# |[GAS-ODOR/LEAK]                                        |6555  |
# |[GAS-ODOR/LEAK, Fire]                                  |6312  |
# |[UNCONSCIOUS SUBJECT]                                  |8148  |
# |[UNCONSCIOUS SUBJECT, EMS]                             |8144  |
# |[GENERAL WEAKNESS]                                     |11430 |
# |[GENERAL WEAKNESS, EMS]                                |11429 |
# |[GENERAL WEAKNESS, EMS, weekday]                       |8424  |
# |[GENERAL WEAKNESS, weekday]                            |8425  |
# |[morning]                                              |187700|
# |[morning, Traffic]                                     |65670 |
# |[morning, Traffic, weekday]                            |53427 |
# |[morning, EMS]                                         |95326 |
# |[morning, EMS, weekday]                                |71823 |
# |[morning, weekday]                                     |145602|
# |[CARDIAC EMERGENCY]                                    |30258 |
# |[CARDIAC EMERGENCY, spring]                            |7971  |
# |[CARDIAC EMERGENCY, spring, EMS]                       |7971  |
# |[CARDIAC EMERGENCY, fall]                              |6611  |
# |[CARDIAC EMERGENCY, fall, EMS]                         |6609  |
# |[CARDIAC EMERGENCY, morning]                           |9687  |
# |[CARDIAC EMERGENCY, morning, EMS]                      |9686  |
# |[CARDIAC EMERGENCY, morning, EMS, weekday]             |7647  |
# |[CARDIAC EMERGENCY, morning, weekday]                  |7648  |
# |[CARDIAC EMERGENCY, winter]                            |8225  |
# |[CARDIAC EMERGENCY, winter, EMS]                       |8222  |
# |[CARDIAC EMERGENCY, EMS]                               |30251 |
# |[CARDIAC EMERGENCY, EMS, weekday]                      |23037 |
# |[CARDIAC EMERGENCY, weekend]                           |7216  |
# |[CARDIAC EMERGENCY, weekend, EMS]                      |7214  |
# |[CARDIAC EMERGENCY, summer]                            |7451  |
# |[CARDIAC EMERGENCY, summer, EMS]                       |7449  |
# |[CARDIAC EMERGENCY, afternoon]                         |9194  |
# |[CARDIAC EMERGENCY, afternoon, EMS]                    |9190  |
# |[CARDIAC EMERGENCY, afternoon, EMS, weekday]           |7229  |
# |[CARDIAC EMERGENCY, afternoon, weekday]                |7231  |
# |[CARDIAC EMERGENCY, evening]                           |6867  |
# |[CARDIAC EMERGENCY, evening, EMS]                      |6865  |
# |[CARDIAC EMERGENCY, weekday]                           |23042 |
# |[ABINGTON]                                             |37843 |
# |[ABINGTON, spring]                                     |9986  |
# |[ABINGTON, spring, weekday]                            |7563  |
# |[ABINGTON, fall]                                       |8527  |
# |[ABINGTON, fall, weekday]                              |6537  |
# |[ABINGTON, Traffic]                                    |12354 |
# |[ABINGTON, Traffic, weekday]                           |9865  |
# |[ABINGTON, VEHICLE ACCIDENT]                           |9460  |
# |[ABINGTON, VEHICLE ACCIDENT, Traffic]                  |8080  |
# |[ABINGTON, VEHICLE ACCIDENT, Traffic, weekday]         |6405  |
# |[ABINGTON, VEHICLE ACCIDENT, weekday]                  |7480  |
# |[ABINGTON, morning]                                    |11298 |
# |[ABINGTON, morning, weekday]                           |8912  |
# |[ABINGTON, winter]                                     |9984  |
# |[ABINGTON, winter, weekday]                            |7483  |
# |[ABINGTON, EMS]                                        |19376 |
# |[ABINGTON, EMS, weekday]                               |14325 |
# |[ABINGTON, weekend]                                    |9101  |
# |[ABINGTON, summer]                                     |9346  |
# |[ABINGTON, summer, weekday]                            |7159  |
# |[ABINGTON, afternoon]                                  |12961 |
# |[ABINGTON, afternoon, weekday]                         |9897  |
# |[ABINGTON, evening]                                    |10035 |
# |[ABINGTON, evening, weekday]                           |7480  |
# |[ABINGTON, weekday]                                    |28742 |
# |[ALTERED MENTAL STATUS]                                |9581  |
# |[ALTERED MENTAL STATUS, EMS]                           |9581  |
# |[ALTERED MENTAL STATUS, EMS, weekday]                  |7090  |
# |[ALTERED MENTAL STATUS, weekday]                       |7090  |
# |[MONTGOMERY]                                           |16454 |
# |[MONTGOMERY, Traffic]                                  |7394  |
# +-------------------------------------------------------+------+
# only showing top 200 rows

# %%
model.associationRules.select("antecedent", "consequent", "confidence").show(truncate=False, n=200)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# +----------------------------------------------+------------------+-------------------+
# |antecedent                                    |consequent        |confidence         |
# +----------------------------------------------+------------------+-------------------+
# |[PLYMOUTH]                                    |[Traffic]         |0.4676349198056528 |
# |[PLYMOUTH]                                    |[VEHICLE ACCIDENT]|0.3618410741340578 |
# |[PLYMOUTH]                                    |[EMS]             |0.4074499764902565 |
# |[PLYMOUTH]                                    |[afternoon]       |0.33974191526043573|
# |[PLYMOUTH]                                    |[weekday]         |0.7628128101980043 |
# |[FALL VICTIM]                                 |[spring]          |0.26537306112439457|
# |[FALL VICTIM]                                 |[fall]            |0.22288639568389432|
# |[FALL VICTIM]                                 |[morning]         |0.31515541659003127|
# |[FALL VICTIM]                                 |[winter]          |0.2642388572129238 |
# |[FALL VICTIM]                                 |[EMS]             |0.9997854208816136 |
# |[FALL VICTIM]                                 |[weekend]         |0.2738029550610018 |
# |[FALL VICTIM]                                 |[summer]          |0.24750168597878733|
# |[FALL VICTIM]                                 |[afternoon]       |0.2909386303721415 |
# |[FALL VICTIM]                                 |[evening]         |0.24839065661210227|
# |[FALL VICTIM]                                 |[weekday]         |0.7261970449389982 |
# |[CARDIAC EMERGENCY, morning, weekday]         |[EMS]             |0.9998692468619247 |
# |[Traffic]                                     |[spring]          |0.24945079883805374|
# |[Traffic]                                     |[weekday]         |0.7826570442992011 |
# |[Traffic]                                     |[morning]         |0.29806644880174293|
# |[Traffic]                                     |[weekend]         |0.21734295570079884|
# |[Traffic]                                     |[evening]         |0.2698484023238925 |
# |[Traffic]                                     |[fall]            |0.2330791575889615 |
# |[Traffic]                                     |[VEHICLE ACCIDENT]|0.6504720406681191 |
# |[Traffic]                                     |[winter]          |0.2694762164124909 |
# |[Traffic]                                     |[summer]          |0.24799382716049384|
# |[Traffic]                                     |[afternoon]       |0.36851397966594046|
# |[Traffic]                                     |[DISABLED VEHICLE]|0.20205156136528685|
# |[summer, VEHICLE ACCIDENT, afternoon, Traffic]|[weekday]         |0.7905219295147963 |
# |[CHELTENHAM, VEHICLE ACCIDENT]                |[Traffic]         |0.8310668877833057 |
# |[CHELTENHAM, VEHICLE ACCIDENT]                |[weekday]         |0.7779988944168048 |
# |[Fire, afternoon, weekday]                    |[FIRE ALARM]      |0.3807888673022184 |
# |[fall, VEHICLE ACCIDENT, Traffic, weekday]    |[morning]         |0.32490426992269344|
# |[fall, VEHICLE ACCIDENT, Traffic, weekday]    |[afternoon]       |0.35748862076439564|
# |[fall, VEHICLE ACCIDENT, Traffic, weekday]    |[evening]         |0.27740047684415864|
# |[summer, VEHICLE ACCIDENT, Traffic, weekday]  |[morning]         |0.2959445585215606 |
# |[summer, VEHICLE ACCIDENT, Traffic, weekday]  |[afternoon]       |0.41042094455852157|
# |[summer, VEHICLE ACCIDENT, Traffic, weekday]  |[evening]         |0.2560501613376357 |
# |[morning, EMS, weekday]                       |[spring]          |0.26431644459295767|
# |[morning, EMS, weekday]                       |[fall]            |0.21991562591370453|
# |[morning, EMS, weekday]                       |[winter]          |0.27002492237862524|
# |[morning, EMS, weekday]                       |[summer]          |0.24574300711471256|
# |[Fire, winter]                                |[morning]         |0.2894237659655187 |
# |[Fire, winter]                                |[afternoon]       |0.3127766302744172 |
# |[Fire, winter]                                |[evening]         |0.2902246764743076 |
# |[Fire, winter]                                |[weekday]         |0.7241074063145471 |
# |[Fire, winter]                                |[weekend]         |0.27589259368545294|
# |[Fire, winter]                                |[FIRE ALARM]      |0.3780297601483792 |
# |[FIRE ALARM, afternoon, weekday]              |[Fire]            |0.9971604353999054 |
# |[evening, VEHICLE ACCIDENT]                   |[spring]          |0.2312835345405768 |
# |[evening, VEHICLE ACCIDENT]                   |[weekend]         |0.2108484238765929 |
# |[evening, VEHICLE ACCIDENT]                   |[Traffic]         |0.7988765928906774 |
# |[evening, VEHICLE ACCIDENT]                   |[weekday]         |0.7891515761234071 |
# |[evening, VEHICLE ACCIDENT]                   |[fall]            |0.24574530516431925|
# |[evening, VEHICLE ACCIDENT]                   |[winter]          |0.2859238765928907 |
# |[evening, VEHICLE ACCIDENT]                   |[summer]          |0.23704728370221329|
# |[night, spring]                               |[EMS]             |0.6634290790642582 |
# |[night, spring]                               |[weekday]         |0.6660349422564407 |
# |[spring, VEHICLE ACCIDENT, morning, Traffic]  |[weekday]         |0.8226855394032134 |
# |[afternoon, EMS, weekday]                     |[spring]          |0.26535908354481197|
# |[afternoon, EMS, weekday]                     |[fall]            |0.21859004688373693|
# |[afternoon, EMS, weekday]                     |[winter]          |0.25993949560554575|
# |[afternoon, EMS, weekday]                     |[summer]          |0.25611137396590533|
# |[HEAD INJURY, EMS]                            |[weekday]         |0.71896982733562   |
# |[weekday]                                     |[spring]          |0.25903071305704584|
# |[weekday]                                     |[Traffic]         |0.3675484760705021 |
# |[weekday]                                     |[morning]         |0.310353427162799  |
# |[weekday]                                     |[evening]         |0.26367316140501207|
# |[weekday]                                     |[fall]            |0.22484114854768955|
# |[weekday]                                     |[VEHICLE ACCIDENT]|0.2964154245239785 |
# |[weekday]                                     |[winter]          |0.2617846355848568 |
# |[weekday]                                     |[EMS]             |0.4842640610978602 |
# |[weekday]                                     |[summer]          |0.2543435028104078 |
# |[weekday]                                     |[afternoon]       |0.3308948756152097 |
# |[ABINGTON, winter]                            |[weekday]         |0.7494991987179487 |
# |[NAUSEA/VOMITING]                             |[EMS]             |0.9997227612974772 |
# |[RESPIRATORY EMERGENCY, fall]                 |[EMS]             |1.0                |
# |[winter, evening, VEHICLE ACCIDENT, Traffic]  |[weekday]         |0.7952705775352433 |
# |[SYNCOPAL EPISODE, weekday]                   |[EMS]             |0.9995907230559345 |
# |[spring, evening, VEHICLE ACCIDENT, Traffic]  |[weekday]         |0.7940203126783065 |
# |[evening, VEHICLE ACCIDENT, Traffic]          |[spring]          |0.229903452618323  |
# |[evening, VEHICLE ACCIDENT, Traffic]          |[weekend]         |0.20337915835869452|
# |[evening, VEHICLE ACCIDENT, Traffic]          |[weekday]         |0.7966208416413055 |
# |[evening, VEHICLE ACCIDENT, Traffic]          |[fall]            |0.2491079861475496 |
# |[evening, VEHICLE ACCIDENT, Traffic]          |[winter]          |0.28846153846153844|
# |[evening, VEHICLE ACCIDENT, Traffic]          |[summer]          |0.23252702277258894|
# |[summer, EMS]                                 |[weekend]         |0.2711495365182846 |
# |[summer, EMS]                                 |[morning]         |0.298423652847102  |
# |[summer, EMS]                                 |[weekday]         |0.7288504634817153 |
# |[summer, EMS]                                 |[afternoon]       |0.30698023836202504|
# |[summer, EMS]                                 |[evening]         |0.26004634817153915|
# |[weekend, afternoon]                          |[spring]          |0.2567467689418909 |
# |[weekend, afternoon]                          |[VEHICLE ACCIDENT]|0.30195161902478973|
# |[weekend, afternoon]                          |[winter]          |0.2685923173728052 |
# |[weekend, afternoon]                          |[summer]          |0.25337088751722897|
# |[weekend, afternoon]                          |[Traffic]         |0.35620542937616106|
# |[weekend, afternoon]                          |[EMS]             |0.49042168554363674|
# |[weekend, afternoon]                          |[fall]            |0.22129002616807494|
# |[FALL VICTIM, spring, EMS]                    |[weekday]         |0.7316312384473198 |
# |[SPRINGFIELD]                                 |[EMS]             |0.5362308857969418 |
# |[SPRINGFIELD]                                 |[weekday]         |0.7463837994214079 |
# |[summer, afternoon]                           |[weekend]         |0.23696452257739084|
# |[summer, afternoon]                           |[VEHICLE ACCIDENT]|0.3276290470229977 |
# |[summer, afternoon]                           |[Traffic]         |0.4004521082818017 |
# |[summer, afternoon]                           |[EMS]             |0.45040820520484987|
# |[summer, afternoon]                           |[weekday]         |0.7630354774226091 |
# |[UPPER MERION, winter]                        |[weekday]         |0.7230062356416147 |
# |[weekend, winter, morning]                    |[EMS]             |0.5453467694131594 |
# |[spring, evening, EMS]                        |[weekday]         |0.7214685513708377 |
# |[night, spring, EMS]                          |[weekday]         |0.6841635422246027 |
# |[RESPIRATORY EMERGENCY, afternoon, weekday]   |[EMS]             |1.0                |
# |[POTTSTOWN]                                   |[spring]          |0.2555258396916542 |
# |[POTTSTOWN]                                   |[morning]         |0.2736962164713286 |
# |[POTTSTOWN]                                   |[winter]          |0.26205458978997875|
# |[POTTSTOWN]                                   |[EMS]             |0.6336820577361756 |
# |[POTTSTOWN]                                   |[weekend]         |0.2723196727758987 |
# |[POTTSTOWN]                                   |[summer]          |0.26205458978997875|
# |[POTTSTOWN]                                   |[afternoon]       |0.31660504994887123|
# |[POTTSTOWN]                                   |[evening]         |0.28014630692991427|
# |[POTTSTOWN]                                   |[weekday]         |0.7276803272241014 |
# |[FIRE ALARM, winter]                          |[weekday]         |0.739435053380783  |
# |[FIRE ALARM, winter]                          |[Fire]            |0.9973309608540926 |
# |[MEDICAL ALERT ALARM, EMS]                    |[weekday]         |0.7307456588355464 |
# |[UPPER GWYNEDD]                               |[weekday]         |0.7826190476190477 |
# |[fall, VEHICLE ACCIDENT, Traffic]             |[weekday]         |0.7956884162115551 |
# |[fall, VEHICLE ACCIDENT, Traffic]             |[morning]         |0.3094567404426559 |
# |[fall, VEHICLE ACCIDENT, Traffic]             |[afternoon]       |0.3644150617993676 |
# |[fall, VEHICLE ACCIDENT, Traffic]             |[weekend]         |0.20431158378844497|
# |[fall, VEHICLE ACCIDENT, Traffic]             |[evening]         |0.2729232538085657 |
# |[CHELTENHAM, Traffic]                         |[weekday]         |0.7786434463794684 |
# |[CHELTENHAM, Traffic]                         |[VEHICLE ACCIDENT]|0.6890009165902842 |
# |[UPPER MERION, VEHICLE ACCIDENT, weekday]     |[Traffic]         |0.8741202493464709 |
# |[RESPIRATORY EMERGENCY, EMS]                  |[spring]          |0.28356383479160785|
# |[RESPIRATORY EMERGENCY, EMS]                  |[fall]            |0.20475428858155362|
# |[RESPIRATORY EMERGENCY, EMS]                  |[morning]         |0.3201931821745539 |
# |[RESPIRATORY EMERGENCY, EMS]                  |[winter]          |0.2905572803963998 |
# |[RESPIRATORY EMERGENCY, EMS]                  |[weekday]         |0.730830746072067  |
# |[RESPIRATORY EMERGENCY, EMS]                  |[weekend]         |0.269169253927933  |
# |[RESPIRATORY EMERGENCY, EMS]                  |[summer]          |0.22112459623043873|
# |[RESPIRATORY EMERGENCY, EMS]                  |[afternoon]       |0.2676952990246809 |
# |[RESPIRATORY EMERGENCY, EMS]                  |[evening]         |0.23680496754163138|
# |[VEHICLE ACCIDENT, afternoon, Traffic]        |[spring]          |0.2551367681584072 |
# |[VEHICLE ACCIDENT, afternoon, Traffic]        |[weekend]         |0.22212313684095583|
# |[VEHICLE ACCIDENT, afternoon, Traffic]        |[fall]            |0.2307314321073034 |
# |[VEHICLE ACCIDENT, afternoon, Traffic]        |[weekday]         |0.7778768631590441 |
# |[VEHICLE ACCIDENT, afternoon, Traffic]        |[winter]          |0.2564471217718893 |
# |[VEHICLE ACCIDENT, afternoon, Traffic]        |[summer]          |0.25768467796240013|
# |[UPPER MORELAND, weekday]                     |[Traffic]         |0.3864226611101045 |
# |[UPPER MORELAND, weekday]                     |[EMS]             |0.5052243763966903 |
# |[FALL VICTIM, spring, weekday]                |[EMS]             |0.9998421218819071 |
# |[DISABLED VEHICLE, winter]                    |[Traffic]         |0.9996025121233802 |
# |[DISABLED VEHICLE, winter]                    |[weekday]         |0.7346370935686461 |
# |[spring, evening, Traffic]                    |[weekday]         |0.7905744365152264 |
# |[spring, evening, Traffic]                    |[VEHICLE ACCIDENT]|0.6191620151204692 |
# |[spring, EMS]                                 |[morning]         |0.3059242080211761 |
# |[spring, EMS]                                 |[weekday]         |0.7329795888631203 |
# |[spring, EMS]                                 |[afternoon]       |0.30207511201233656|
# |[spring, EMS]                                 |[evening]         |0.2559830979758855 |
# |[spring, EMS]                                 |[weekend]         |0.2670204111368797 |
# |[evening, Traffic]                            |[spring]          |0.23805358854893782|
# |[evening, Traffic]                            |[weekend]         |0.21489243604191546|
# |[evening, Traffic]                            |[weekday]         |0.7851075639580846 |
# |[evening, Traffic]                            |[VEHICLE ACCIDENT]|0.6411114662001918 |
# |[evening, Traffic]                            |[fall]            |0.23712848804938355|
# |[evening, Traffic]                            |[winter]          |0.2788589305838225 |
# |[evening, Traffic]                            |[summer]          |0.24595899281785613|
# |[evening, Traffic]                            |[DISABLED VEHICLE]|0.22596000201840108|
# |[summer, afternoon, Traffic]                  |[VEHICLE ACCIDENT]|0.6605551667832984 |
# |[summer, afternoon, Traffic]                  |[weekday]         |0.7934219734079776 |
# |[night, Traffic]                              |[weekday]         |0.6405826074539483 |
# |[night, Traffic]                              |[VEHICLE ACCIDENT]|0.5284163929744395 |
# |[Fire, spring]                                |[morning]         |0.2722776324395029 |
# |[Fire, spring]                                |[afternoon]       |0.3292184434270765 |
# |[Fire, spring]                                |[evening]         |0.30183126226291696|
# |[Fire, spring]                                |[weekday]         |0.7378597122302158 |
# |[Fire, spring]                                |[weekend]         |0.26214028776978415|
# |[Fire, spring]                                |[FIRE ALARM]      |0.36895029431000653|
# |[FIRE ALARM, weekday]                         |[spring]          |0.24662671421743446|
# |[FIRE ALARM, weekday]                         |[fall]            |0.23482480973565203|
# |[FIRE ALARM, weekday]                         |[morning]         |0.32571050406264934|
# |[FIRE ALARM, weekday]                         |[winter]          |0.24445751682047134|
# |[FIRE ALARM, weekday]                         |[summer]          |0.27409095922644217|
# |[FIRE ALARM, weekday]                         |[Fire]            |0.9971690135666752 |
# |[FIRE ALARM, weekday]                         |[afternoon]       |0.3107467186293614 |
# |[FIRE ALARM, weekday]                         |[evening]         |0.2535387330416559 |
# |[spring, VEHICLE ACCIDENT, afternoon]         |[Traffic]         |0.8208806651832767 |
# |[spring, VEHICLE ACCIDENT, afternoon]         |[weekday]         |0.7774329546785338 |
# |[DISABLED VEHICLE, fall]                      |[Traffic]         |1.0                |
# |[DISABLED VEHICLE, fall]                      |[weekday]         |0.7883982180902576 |
# |[spring, weekday]                             |[Traffic]         |0.354720055297719  |
# |[spring, weekday]                             |[VEHICLE ACCIDENT]|0.2786774628879892 |
# |[spring, weekday]                             |[morning]         |0.30721503571311015|
# |[spring, weekday]                             |[EMS]             |0.4967413844178928 |
# |[spring, weekday]                             |[afternoon]       |0.3386738422040091 |
# |[spring, weekday]                             |[evening]         |0.2615697310819262 |
# |[DISABLED VEHICLE, morning, Traffic]          |[weekday]         |0.8119866634138407 |
# |[winter, morning, weekday]                    |[VEHICLE ACCIDENT]|0.3009721058910125 |
# |[winter, morning, weekday]                    |[Traffic]         |0.3774207467194599 |
# |[winter, morning, weekday]                    |[EMS]             |0.49224599609127134|
# |[afternoon, weekday]                          |[spring]          |0.2651202339618266 |
# |[afternoon, weekday]                          |[fall]            |0.22106558274660362|
# +----------------------------------------------+------------------+-------------------+
# only showing top 200 rows
